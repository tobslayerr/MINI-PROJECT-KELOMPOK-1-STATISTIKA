# %% [markdown]
# # Ega - Final Evaluation, Save Model, dan Demo Prediction
#
# Bagian ini membandingkan Logistic Regression dan Random Forest, memilih model terbaik, menyimpan model, dan membuat fungsi demo prediksi.
#
# Output yang diharapkan:
# - File `model_metrics.csv`
# - Model terbaik `best_ott_model.joblib`
# - Fungsi demo prediksi
# - File `final_project_summary.json`
